# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import oracledb
import getpass
from scipy import stats
from sqlalchemy import create_engine, text

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
def getODBconn(user, hostname, db, pw = None):
    if pw == None:
        print("Enter password for " + user + "@" + db + ": ")
        pw = getpass.getpass()
    connection=oracledb.connect(user=user, password=pw, host=hostname, service_name=db)
    engine = create_engine('oracle+oracledb://', creator=lambda: connection)
    return engine

# %%
eng = getODBconn('VALESA10_SQL', 'AIX47', 'BCDWHPRD')
# Out:
# Enter password for VALESA10_SQL@BCDWHPRD:
# ········

# %%
sql = text('''
SELECT ADDR_NUM, PARENT_ADDR_NUM, NAME_ALPHA, ADDRESS_LINE_1, ADDRESS_LINE_2, ADDRESS_LINE_3, ADDRESS_LINE_4, CITY, STATE_CD, STATE, ZIP, COUNTY, COUNTRY_CD, COUNTRY, LATITUDE, LONGITUDE
    FROM CUSTOMER
''')

# %%
cnx = eng.connect()
qry = cnx.execute(sql)
sql_df = pd.DataFrame(qry.fetchall())
sql_df.columns = qry.keys()

# %%
sql_df
# Out:
#        addr_num  parent_addr_num                                name_alpha  \
# 0        137313           137313  03112 MAISON FUNER. RACINE ROBERT & GAUT
# 1        315569           143672    3833 COMPLEXE FUNERAIRE SYLVIO MARCEAU
# 2        321862           321862            03741 PEOPLES MEMORIAL SOCIETY
# 3        148221           134149           3722 COURTNEY'S FUNERAL SERVICE
# 4        286863           286863                 ROSHELL FREIGHT SOLUTIONS
# ...         ...              ...                                       ...
# 66370    287086           287086          SIMONS-COLEMAN FUNERAL HOME,INC.
# 66371    723127           151849                CROSBY & NEAL FUNERAL HOME
# 66372    173540           173540                 PRE-NEED MARKETING AGENCY
# 66373    314504           314504                       G LANE FUNERAL HOME
# 66374    301278           301278         STEBBINS MC CULLOUGH FUNERAL HOME
#
#                      address_line_1 address_line_2 address_line_3  \
# 0                271 BOUL ST-JOSEPH
# 1      270 RUE MARIE DE IINCARNATIO
# 2                    2805-44 AVENUE
# 3                       PO BOX 1558
# 4                       P O BOX #88
# ...                             ...            ...            ...
# 66370                    PO BOX 647
# 66371                    PO BOX 371
# 66372                  PO BOX 27563
# 66373                P.O. BOX 30035
# 66374                     PO BOX 21
#
#       address_line_4          city state_cd             state         zip  \
# 0                             HULL       QC            Quebec     J8Y 3Y1
# 1                           QUEBEC       QC            Quebec     G1N 3G4
# 2                           VERNON       BC  British Columbia     V1T 7P4
# 3                            HANNA       AB           Alberta     T0J 1P0
# 4                     PETERBOROUGH       ON           Ontario     K9J 6Y5
# ...              ...           ...      ...               ...         ...
# 66370                     RICHWOOD       WV     West Virginia  26261-0647
# 66371                       DEXTER       ME             Maine  04930-0371
# 66372                        OMAHA       NE          Nebraska   68127-056
# 66373                   GREENVILLE       NC    North Carolina  27833-0035
# 66374                       EDMORE       MI          Michigan       48829
#
#                  county country_cd country       latitude       longitude
# 0                QUEBEC         CA  CANADA     45.4377825      -75.732955
# 1                QUEBEC         CA  CANADA  46.8081608632  -71.2453193395
# 2      BRITISH COLUMBIA         CA  CANADA       50.27619    -119.2685524
# 3               ALBERTA         CA  CANADA              0               0
# 4               ONTARIO         CA  CANADA              0               0
# ...                 ...        ...     ...            ...             ...
# 66370                           US     USA              0               0
# 66371                           US     USA              0               0
# 66372                           US     USA              0               0
# 66373              PITT         US     USA              0               0
# 66374                           US     USA              0               0
#
# [66375 rows x 16 columns]
